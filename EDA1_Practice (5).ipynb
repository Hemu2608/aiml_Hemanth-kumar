# %%
#load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data_clean.csv")
print(data)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
# Printing the information 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
# Dataframe attributes
print(type(data))
print(data.shape)
print(data.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)
# 1580

# %%
# Drop dupplicate column( Temp C) and Unnamed column

# data1 = data.drop(['Unnamed: 0',"Temp C"], axis =1, inplace = True)
data1 = data.drop(['Unnamed: 0',"Temp C"], axis =1)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
# Convert the Month column data type to float data type

data1['Month']=pd.to_numeric(data['Month'],errors='coerce')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
# Print all duplicated rows
data1[data1.duplicated(keep = False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
# Checking for duplicated rows in the table
#Print only the duplicated row (one) only
data1[data1.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
# Drop duplicated rows
data1.drop_duplicates(keep='first', inplace = True)
data1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
# Change column names (Rename the columns)
data1.rename({'Solar.R': 'Solar'}, axis=1, inplace = True)
data1
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# #### Impute the missing values

# %%
data1.rename({'solar.R': 'solar'}, axis=1, inplace = True)
data1
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data1.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
cols = data1.columns
colours = ['black','yellow']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colours),cbar = True)
# Out:
# <Axes: >

# %%
median_ozone = data1["Ozone"].median()
mean_ozone = data1["Ozone"].mean()
print("Median of Ozone: ", median_ozone)
print("Mean of Ozone: ", mean_ozone)
# Out:
# Median of Ozone:  31.0
# Mean of Ozone:  41.81512605042017

# %%
data1['Ozone'] = data1['Ozone'].fillna(median_ozone)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
median_solar = data1["Solar"].median()
mean_solar = data1["Solar"].mean()
print("Median of Solar: ", median_solar)
print("Mean of Solar: ", mean_solar)
# Out:
# Median of Solar:  199.0
# Mean of Solar:  185.36666666666667

# %%
data1['Solar'] = data1['Solar'].fillna(median_solar)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
print(data1["Weather"].value_counts())
mode_weather = data1["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
data1["Weather"] = data1["Weather"].fillna(mode_weather)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
print(data1["Month"].value_counts())
mode_month = data1["Month"].mode()[0]
print(mode_month)
# Out:
# Month
# 9.0    33
# 5.0    31
# 7.0    31
# 8.0    31
# 6.0    30
# Name: count, dtype: int64
# 9.0

# %%
data1["Month"] = data1["Month"].fillna(mode_month)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
data1.tail()
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   31.0  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C

# %%
data1.reset_index(drop=True)
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4     31.0  199.0  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   31.0  145.0  13.2    9.0   27  2010    77       S
# 156   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#Create a figure with two subplots ,stacked vertically
fig, axes=plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios':[1, 3]})
#Plot the boxplot in the first (top) subplot
sns.boxplot(data=data1["Ozone"], ax=axes[0],color='skyblue',width=0.5, orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")

#Plot the histogram with KDE Curve in the second (bottom) subplot
sns.histplot(data1["Ozone"], kde=True, ax=axes[1],color='purple',bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
 
#Adjust layout for better spacing
plt.tight_layout()

#Show the plot
plt.show()

# %%
#Create a figure with two subplots ,stacked vertically
fig, axes=plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios':[1, 3]})
#Plot the boxplot in the first (top) subplot
sns.boxplot(data=data1["Solar"], ax=axes[0],color='skyblue',width=0.5, orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Solar Levels")

#Plot the histogram with KDE Curve in the second (bottom) subplot
sns.histplot(data1["Solar"], kde=True, ax=axes[1],color='purple',bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Solar Levels")
axes[1].set_ylabel("Frequency")
 
#Adjust layout for better spacing
plt.tight_layout()

#Show the plot
plt.show()

# %%
plt.figure(figsize=(6,2))
plt.boxplot(data1["Ozone"], vert= False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e5a26412e0>,
#   <matplotlib.lines.Line2D at 0x1e5a26428a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e5a0d11a30>,
#   <matplotlib.lines.Line2D at 0x1e5a25b32c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e5a2659cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e5a265a060>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e5a265a210>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
boxplot_data = plt.boxplot(data1["Ozone"], vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %%
#Method 2 for outlier detection
data1["Ozone"].describe()
# Out:
# count    157.000000
# mean      39.197452
# std       28.781992
# min        1.000000
# 25%       21.000000
# 50%       31.000000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu = data1["Ozone"].describe()[1]
sigma = data1["Ozone"].describe()[2]
for x in data1["Ozone"]:
    if ((x < (mu - 3*sigma)) or (x > (mu + 3*sigma))):
        print(x)
# Out:
# 135.0
# 168.0
# C:\Users\gundu\AppData\Local\Temp\ipykernel_6260\2621657408.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu = data1["Ozone"].describe()[1]
# C:\Users\gundu\AppData\Local\Temp\ipykernel_6260\2621657408.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma = data1["Ozone"].describe()[2]

# %% [markdown]
# Observation
# .it is observed that only two outliers are idenfied using std method
# .in box plot method more no of outliers are identified
# .this is because the assumption of normality is not satisfied in this column

# %%
import scipy.stats as stats
#create Q-Q plot
plt.figure(figsize=(8,6))
stats.probplot(data1["Ozone"], dist="norm", plot=plt)
plt.title("Q-Q plot for outlier Detection", fontsize=14)
plt.xlabel("Theoretical Quantiles", fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %% [markdown]
# observation from Q-Q plot
# .the data does not follow normal distribution as the points are deviating sigificantly aways from the red line
# .the data shows a right-skewed distribution and possible outliers

# %%
import scipy.stats as stats
#create Q-Q plot
plt.figure(figsize=(8,6))
stats.probplot(data1["Solar"], dist="norm", plot=plt)
plt.title("Q-Q plot for outlier Detection", fontsize=14)
plt.xlabel("Theoretical Quantiles", fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %%
#other visualisation that could help understand the data
#create a figure for violin plot
sns.violinplot(data=data1["Ozone"], color='lightgreen')
plt.show()

# %%
sns.swarmplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set2", size=6)
# Out:
# C:\Users\gundu\AppData\Local\Temp\ipykernel_6260\1222012946.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set2", size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.stripplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set1", size=6, jitter = True)
# Out:
# C:\Users\gundu\AppData\Local\Temp\ipykernel_6260\2160529860.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set1", size=6, jitter = True)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.kdeplot(data=data1["Ozone"], fill=True, color="blue")
sns.rugplot(data=data1["Ozone"], color="black")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
sns.boxplot(data = data1, x = "Weather", y="Ozone")
# Out:
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
plt.scatter(data1["Wind"], data1["Temp"])

# %%
data1["Wind"].corr(data1["Temp"])
# Out:
# -0.44122806925588215

# %% [markdown]
# We can observed that it have mild strength negative correlation between two variables

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    157 non-null    float64
#  1   Solar    157 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  157 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 11.0+ KB

# %%
data1_numeric = data1.iloc[:,[0,1,2,6]]
data1_numeric
# Out:
#      Ozone  Solar  Wind  Temp
# 0     41.0  190.0   7.4    67
# 1     36.0  118.0   8.0    72
# 2     12.0  149.0  12.6    74
# 3     18.0  313.0  11.5    62
# 4     31.0  199.0  14.3    56
# ..     ...    ...   ...   ...
# 152   20.0  223.0  11.5    68
# 153   41.0  190.0   7.4    67
# 154   30.0  193.0   6.9    70
# 155   31.0  145.0  13.2    77
# 157   18.0  131.0   8.0    76
#
# [157 rows x 4 columns]

# %%
data1_numeric.corr()
# Out:
#           Ozone     Solar      Wind      Temp
# Ozone  1.000000  0.297561 -0.523738  0.597087
# Solar  0.297561  1.000000 -0.057709  0.256994
# Wind  -0.523738 -0.057709  1.000000 -0.441228
# Temp   0.597087  0.256994 -0.441228  1.000000

# %% [markdown]
# Observation
# .Maximun higher correlation between the strength is observed between Ozone and Temperature(0.597087)
# .the next maximun higher correlation strength is observed between Ozone and wind(-0.523738)
# .the next maximun higher correlation strength is observed between wind and temp(-0.441228)
# .the least correlation strength is observed between solar and wind(-0.057709)

# %%
sns.pairplot(data1_numeric)

# %%
#Transformations
#creating dummy variable for weather column
data2=pd.get_dummies(data1,columns=['Month','Weather'])
data2
# Out:
#      Ozone  Solar  Wind  Day  Year  Temp  Month_5.0  Month_6.0  Month_7.0  \
# 0     41.0  190.0   7.4    1  2010    67       True      False      False
# 1     36.0  118.0   8.0    2  2010    72       True      False      False
# 2     12.0  149.0  12.6    3  2010    74       True      False      False
# 3     18.0  313.0  11.5    4  2010    62       True      False      False
# 4     31.0  199.0  14.3    5  2010    56       True      False      False
# ..     ...    ...   ...  ...   ...   ...        ...        ...        ...
# 152   20.0  223.0  11.5   30  2010    68      False      False      False
# 153   41.0  190.0   7.4    1  2010    67       True      False      False
# 154   30.0  193.0   6.9   26  2010    70      False      False      False
# 155   31.0  145.0  13.2   27  2010    77      False      False      False
# 157   18.0  131.0   8.0   29  2010    76      False      False      False
#
#      Month_8.0  Month_9.0  Weather_C  Weather_PS  Weather_S
# 0        False      False      False       False       True
# 1        False      False       True       False      False
# 2        False      False      False        True      False
# 3        False      False      False       False       True
# 4        False      False      False       False       True
# ..         ...        ...        ...         ...        ...
# 152      False       True      False       False       True
# 153      False      False       True       False      False
# 154      False       True      False        True      False
# 155      False       True      False       False       True
# 157      False       True       True       False      False
#
# [157 rows x 14 columns]

# %% [markdown]
# Normalization of the data

# %%
data1_numeric.values
# Out:
# array([[ 41. , 190. ,   7.4,  67. ],
#        [ 36. , 118. ,   8. ,  72. ],
#        [ 12. , 149. ,  12.6,  74. ],
#        [ 18. , 313. ,  11.5,  62. ],
#        [ 31. , 199. ,  14.3,  56. ],
#        [ 28. , 199. ,  14.9,  66. ],
#        [ 23. , 299. ,   8.6,  65. ],
#        [ 19. ,  99. ,  13.8,  59. ],
#        [  8. ,  19. ,  20.1,  61. ],
#        [ 31. , 194. ,   8.6,  69. ],
#        [  7. , 199. ,   6.9,  74. ],
#        [ 16. , 256. ,   9.7,  69. ],
#        [ 11. , 290. ,   9.2,  66. ],
#        [ 14. , 274. ,  10.9,  68. ],
#        [ 18. ,  65. ,  13.2,  58. ],
#        [ 14. , 334. ,  11.5,  64. ],
#        [ 34. , 307. ,  12. ,  66. ],
#        [  6. ,  78. ,  18.4,  57. ],
#        [ 30. , 322. ,  11.5,  68. ],
#        [ 11. ,  44. ,   9.7,  62. ],
#        [  1. ,   8. ,   9.7,  59. ],
#        [ 11. , 320. ,  16.6,  73. ],
#        [  4. ,  25. ,   9.7,  61. ],
#        [ 32. ,  92. ,  12. ,  61. ],
#        [ 31. ,  66. ,  16.6,  57. ],
#        [ 31. , 266. ,  14.9,  58. ],
#        [ 31. , 199. ,   8. ,  57. ],
#        [ 23. ,  13. ,  12. ,  67. ],
#        [ 45. , 252. ,  14.9,  81. ],
#        [115. , 223. ,   5.7,  79. ],
#        [ 37. , 279. ,   7.4,  76. ],
#        [ 31. , 286. ,   8.6,  78. ],
#        [ 31. , 287. ,   9.7,  74. ],
#        [ 31. , 242. ,  16.1,  67. ],
#        [ 31. , 186. ,   9.2,  84. ],
#        [ 31. , 220. ,   8.6,  85. ],
#        [ 31. , 264. ,  14.3,  79. ],
#        [ 29. , 127. ,   9.7,  82. ],
#        [ 31. , 273. ,   6.9,  87. ],
#        [ 71. , 291. ,  13.8,  90. ],
#        [ 39. , 323. ,  11.5,  87. ],
#        [ 31. , 259. ,  10.9,  93. ],
#        [ 31. , 250. ,   9.2,  92. ],
#        [ 23. , 148. ,   8. ,  82. ],
#        [ 31. , 332. ,  13.8,  80. ],
#        [ 31. , 322. ,  11.5,  79. ],
#        [ 21. , 191. ,  14.9,  77. ],
#        [ 37. , 284. ,  20.7,  72. ],
#        [ 20. ,  37. ,   9.2,  65. ],
#        [ 12. , 120. ,  11.5,  73. ],
#        [ 13. , 137. ,  10.3,  76. ],
#        [ 31. , 150. ,   6.3,  77. ],
#        [ 31. ,  59. ,   1.7,  76. ],
#        [ 31. ,  91. ,   4.6,  76. ],
#        [ 31. , 250. ,   6.3,  76. ],
#        [ 31. , 135. ,   8. ,  75. ],
#        [ 31. , 127. ,   8. ,  78. ],
#        [ 31. ,  47. ,  10.3,  73. ],
#        [ 31. ,  98. ,  11.5,  80. ],
#        [ 31. ,  31. ,  14.9,  77. ],
#        [ 31. , 138. ,   8. ,  83. ],
#        [135. , 269. ,   4.1,  84. ],
#        [ 49. , 248. ,   9.2,  85. ],
#        [ 32. , 236. ,   9.2,  81. ],
#        [ 31. , 101. ,  10.9,  84. ],
#        [ 64. , 175. ,   4.6,  83. ],
#        [ 40. , 314. ,  10.9,  83. ],
#        [ 77. , 276. ,   5.1,  88. ],
#        [ 97. , 267. ,   6.3,  92. ],
#        [ 97. , 272. ,   5.7,  92. ],
#        [ 85. , 175. ,   7.4,  89. ],
#        [ 31. , 139. ,   8.6,  82. ],
#        [ 10. , 264. ,  14.3,  73. ],
#        [ 27. , 175. ,  14.9,  81. ],
#        [ 31. , 291. ,  14.9,  91. ],
#        [  7. ,  48. ,  14.3,  80. ],
#        [ 48. , 260. ,   6.9,  81. ],
#        [ 35. , 274. ,  10.3,  82. ],
#        [ 61. , 285. ,   6.3,  84. ],
#        [ 79. , 187. ,   5.1,  87. ],
#        [ 63. , 220. ,  11.5,  85. ],
#        [ 16. ,   7. ,   6.9,  74. ],
#        [ 31. , 258. ,   9.7,  81. ],
#        [ 31. , 295. ,  11.5,  82. ],
#        [ 80. , 294. ,   8.6,  86. ],
#        [108. , 223. ,   8. ,  85. ],
#        [ 20. ,  81. ,   8.6,  82. ],
#        [ 52. ,  82. ,  12. ,  86. ],
#        [ 82. , 213. ,   7.4,  88. ],
#        [ 50. , 275. ,   7.4,  86. ],
#        [ 64. , 253. ,   7.4,  83. ],
#        [ 59. , 254. ,   9.2,  81. ],
#        [ 39. ,  83. ,   6.9,  81. ],
#        [  9. ,  24. ,  13.8,  81. ],
#        [ 16. ,  77. ,   7.4,  82. ],
#        [ 78. , 199. ,   6.9,  86. ],
#        [ 35. , 199. ,   7.4,  85. ],
#        [ 66. , 199. ,   4.6,  87. ],
#        [122. , 255. ,   4. ,  89. ],
#        [ 89. , 229. ,  10.3,  90. ],
#        [110. , 207. ,   8. ,  90. ],
#        [ 31. , 222. ,   8.6,  92. ],
#        [ 31. , 137. ,  11.5,  86. ],
#        [ 44. , 192. ,  11.5,  86. ],
#        [ 28. , 273. ,  11.5,  82. ],
#        [ 65. , 157. ,   9.7,  80. ],
#        [ 31. ,  64. ,  11.5,  79. ],
#        [ 22. ,  71. ,  10.3,  77. ],
#        [ 59. ,  51. ,   6.3,  79. ],
#        [ 23. , 115. ,   7.4,  76. ],
#        [ 31. , 244. ,  10.9,  78. ],
#        [ 44. , 190. ,  10.3,  78. ],
#        [ 21. , 259. ,  15.5,  77. ],
#        [  9. ,  36. ,  14.3,  72. ],
#        [ 31. , 255. ,  12.6,  75. ],
#        [ 45. , 212. ,   9.7,  79. ],
#        [168. , 238. ,   3.4,  81. ],
#        [ 73. , 215. ,   8. ,  86. ],
#        [ 31. , 153. ,   5.7,  88. ],
#        [ 76. , 203. ,   9.7,  97. ],
#        [118. , 225. ,   2.3,  94. ],
#        [ 84. , 237. ,   6.3,  96. ],
#        [ 85. , 188. ,   6.3,  94. ],
#        [ 96. , 167. ,   6.9,  91. ],
#        [ 78. , 197. ,   5.1,  92. ],
#        [ 73. , 183. ,   2.8,  93. ],
#        [ 91. , 189. ,   4.6,  93. ],
#        [ 47. ,  95. ,   7.4,  87. ],
#        [ 32. ,  92. ,  15.5,  84. ],
#        [ 20. , 252. ,  10.9,  80. ],
#        [ 23. , 220. ,  10.3,  78. ],
#        [ 21. , 230. ,  10.9,  75. ],
#        [ 24. , 259. ,   9.7,  73. ],
#        [ 44. , 236. ,  14.9,  81. ],
#        [ 21. , 259. ,  15.5,  76. ],
#        [ 28. , 238. ,   6.3,  77. ],
#        [  9. ,  24. ,  10.9,  71. ],
#        [ 13. , 112. ,  11.5,  71. ],
#        [ 46. , 237. ,   6.9,  78. ],
#        [ 18. , 224. ,  13.8,  67. ],
#        [ 13. ,  27. ,  10.3,  76. ],
#        [ 24. , 238. ,  10.3,  68. ],
#        [ 16. , 201. ,   8. ,  82. ],
#        [ 13. , 238. ,  12.6,  64. ],
#        [ 23. ,  14. ,   9.2,  71. ],
#        [ 36. , 139. ,  10.3,  81. ],
#        [  7. ,  49. ,  10.3,  69. ],
#        [ 14. ,  20. ,  16.6,  63. ],
#        [ 30. , 193. ,   6.9,  70. ],
#        [ 31. , 145. ,  13.2,  77. ],
#        [ 14. , 191. ,  14.3,  75. ],
#        [ 18. , 131. ,   8. ,  76. ],
#        [ 20. , 223. ,  11.5,  68. ],
#        [ 41. , 190. ,   7.4,  67. ],
#        [ 30. , 193. ,   6.9,  70. ],
#        [ 31. , 145. ,  13.2,  77. ],
#        [ 18. , 131. ,   8. ,  76. ]])

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

array = data1_numeric.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledx = scaler.fit_transform(array)

set_printoptions(precision=2)
print(rescaledx[0:10,:])
# Out:
# [[0.24 0.56 0.3  0.27]
#  [0.21 0.34 0.33 0.39]
#  [0.07 0.43 0.57 0.44]
#  [0.1  0.94 0.52 0.15]
#  [0.18 0.59 0.66 0.  ]
#  [0.16 0.59 0.69 0.24]
#  [0.13 0.89 0.36 0.22]
#  [0.11 0.28 0.64 0.07]
#  [0.04 0.04 0.97 0.12]
#  [0.18 0.57 0.36 0.32]]
